# %%
import numpy as np
import os
import pandas as pd
import csv
from matplotlib import pyplot as plt
import matplotlib.pyplot as pyplot
import PIL.Image as Image
from PIL import ImageOps
import glob
import math

# %%
df = pd.read_csv("abalone.DATA", header = None )

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
df1 = df
df1 = df1.drop([0],axis=1)
y=df.iloc[:,-1]

df1 = df1.drop(df1.columns[-1],axis=1)

x=df1

#x,_,y,_ = train_test_split(x,y,test_size=0.0)

reg = linear_model.LinearRegression()

reg.fit(x,y)
x_r_1 = reg.predict(x)
y_r = reg.predict(x)-y

plt.scatter(x_r_1 ,y_r ,color ='green')
plt.hlines(y = 0, xmin = -5, xmax = 25)
plt.title('Residual Plot, no gender')
plt.show()
print(np.mean((y-x_r_1 ** 2)))
# Out:
# -94.22794297829185

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
df1 = df
df1 = df1.drop([0],axis=1)
y=df.iloc[:,-1]
df1.iloc[:,0] = df1.iloc[:,0].astype('category')
df1.iloc[:,0] = df1.iloc[:,0].cat.codes

y=df.iloc[:,-1]

df1 = df1.drop(df1.columns[-1],axis=1)

x=df1

#x,_,y,_ = train_test_split(x,y,test_size=0.0)

reg = linear_model.LinearRegression()

reg.fit(x,y)
x_r = reg.predict(x)
y_r = reg.predict(x)-y

plt.scatter(x_r ,y_r ,color ='green')
plt.hlines(y = 0, xmin = -5, xmax = 25)
plt.title('Residual Plot, with gender')
plt.show()
print(np.mean((y-x_r ** 2)))
# Out:
# -94.2280697033864

# %%
print(x_r_1)
# Out:
# [  8.77893882   7.23758471  10.84589582 ...,  10.88079477   9.6174032
#   11.04119896]

# %%
print(x_r)
# Out:
# [  8.7805948    7.23837816  10.84601247 ...,  10.88171054   9.61652208
#   11.04121903]

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
df1 = df
df1 = df1.drop([0],axis=1)
y_o =np.asarray(df.iloc[:,-1])

y=np.log(df.iloc[:,-1])


df1 = df1.drop(df1.columns[-1],axis=1)

x=df1

#x,_,y,_ = train_test_split(x,y,test_size=0.0)

reg = linear_model.LinearRegression()

reg.fit(x,y)
x_r_1 = reg.predict(x)
y_r = np.exp(reg.predict(x))-y_o

plt.scatter(x_r_1 ,y_r ,color ='green')
plt.hlines(y = 0, xmin = 0, xmax = 5)
plt.title('Residual Plot, no gender, log age')
plt.show()
print(np.mean((y-x_r_1 ** 2)))
# Out:
# -2.8571517769441828

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
df1 = df
df1.iloc[:,0] = df1.iloc[:,0].astype('category')
df1.iloc[:,0] = df1.iloc[:,0].cat.codes

y= np.log(df.iloc[:,-1])
y_o =np.asarray(df.iloc[:,-1])

df1 = df1.drop(df1.columns[-1],axis=1)

x=df1

#x,_,y,_ = train_test_split(x,y,test_size=0.0)

reg = linear_model.LinearRegression()

reg.fit(x,y)
x_r = reg.predict(x)
y_r = np.exp(reg.predict(x))-y_o

plt.scatter(x_r ,y_r ,color ='green')
plt.hlines(y = 0, xmin = 0, xmax = 5)
plt.title('Residual Plot, with gender , log age')
plt.show()

print(np.mean((y-x_r ** 2)))
# Out:
# -2.857199167549198

# %%
import glmnet_python
from glmnet import glmnet

from glmnet import glmnet; from glmnetPlot import glmnetPlot 
from glmnetPrint import glmnetPrint; from glmnetCoef import glmnetCoef; from glmnetPredict import glmnetPredict
from cvglmnet import cvglmnet; from cvglmnetCoef import cvglmnetCoef
from cvglmnetPlot import cvglmnetPlot; from cvglmnetPredict import cvglmnetPredict

# %%
x = x.as_matrix()
y = y.as_matrix()

# %%
cvfit = cvglmnet(x = x.copy(), y = y.copy(), ptype = 'mse', nfolds = 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-adea72643a3e> in <module>()
# ----> 1 cvfit = cvglmnet(x = x.copy(), y = y.copy(), ptype = 'mse', nfolds = 20)
#
# C:\Users\titus\Anaconda3\lib\site-packages\glmnet_python\cvglmnet.py in cvglmnet(x, y, family, ptype, nfolds, foldid, parallel, keep, grouped, **options)
#     241
#     242     # main call to glmnet
# --> 243     glmfit = glmnet(x = x, y = y, family = family, **options)
#     244
#     245     is_offset = glmfit['offset']
#
# C:\Users\titus\Anaconda3\lib\site-packages\glmnet_python\glmnet.py in glmnet(x, y, family, **options)
#     448         fit = elnet(x, is_sparse, irs, pcs, y, weights, offset, gtype, parm,
#     449                     lempty, nvars, jd, vp, cl, ne, nx, nlam, flmin, ulam,
# --> 450                     thresh, isd, intr, maxit, family)
# ...

# %%
cvglmnetPlot(cvmfit)
